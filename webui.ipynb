# %% [markdown]
# <a href="https://colab.research.google.com/github/RedeatI/GPT-SoVITS/blob/main/webui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 环境配置 environment

# %%
# !pip install -q condacolab
# Setting up condacolab and installing packages
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/miniconda/Miniconda3-py39_23.11.0-2-Linux-x86_64.sh")
# %cd -q /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# !conda install -y -q -c pytorch -c nvidia cudatoolkit
# %cd -q /content/GPT-SoVITS
# !conda install -y -q -c conda-forge gcc gxx ffmpeg cmake -c pytorch -c nvidia
# !/usr/local/bin/pip install -r requirements.txt
# Out:
# ✨🍰✨ Everything looks OK!
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.
# Error while loading conda entry point: conda-libmamba-solver (libarchive.so.19: cannot open shared object file: No such file or directory)
#
# CondaValueError: You have chosen a non-default solver backend (libmamba) but it was not recognized. Choose one of: classic
#
# Error while loading conda entry point: conda-libmamba-solver (libarchive.so.19: cannot open shared object file: No such file or directory)
#
# CondaValueError: You have chosen a non-default solver backend (libmamba) but it was not recognized. Choose one of: classic
#
# Ignoring onnxruntime: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring opencc: markers 'sys_platform == "win32"' don't match your environment
# Ignoring eunjeon: markers 'sys_platform == "win32"' don't match your environment
# Requirement already satisfied: numpy==1.23.4 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (2.17.0)
# Requirement already satisfied: librosa==0.9.2 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.9.2)
# Requirement already satisfied: numba==0.56.4 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.56.4)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.3.3)
# Requirement already satisfied: gradio==3.38.0 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (3.38.0)
# Requirement already satisfied: gradio_client==0.8.1 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.8.1)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: onnxruntime-gpu in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (1.18.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (4.66.5)
# Requirement already satisfied: funasr==1.0.27 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (1.0.27)
# Requirement already satisfied: cn2an in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (0.5.22)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.52.0)
# Requirement already satisfied: pyopenjtalk in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.3.4)
# Requirement already satisfied: g2p_en in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (2.1.0)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (2.4.0)
# Requirement already satisfied: modelscope==1.10.0 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (1.10.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (4.43.4)
# Requirement already satisfied: chardet in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (5.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (6.0.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (6.0.0)
# Requirement already satisfied: jieba_fast in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.53)
# Requirement already satisfied: jieba in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (0.42.1)
# Requirement already satisfied: LangSegment>=0.2.0 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.3.3)
# Requirement already satisfied: Faster_Whisper in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (1.0.3)
# Requirement already satisfied: wordsegment in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (1.3.1)
# Requirement already satisfied: rotary_embedding_torch in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (0.6.4)
# Requirement already satisfied: pyjyutping in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (1.0.0)
# Requirement already satisfied: g2pk2 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (0.0.3)
# Requirement already satisfied: ko_pron in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (1.3)
# Requirement already satisfied: opencc==1.1.1 in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (1.1.1)
# Requirement already satisfied: python_mecab_ko in /usr/local/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (1.3.7)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.9/site-packages (from librosa==0.9.2->-r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.9/site-packages (from librosa==0.9.2->-r requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.9/site-packages (from librosa==0.9.2->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.9/site-packages (from librosa==0.9.2->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.9/site-packages (from librosa==0.9.2->-r requirements.txt (line 4)) (0.4.3)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.9/site-packages (from librosa==0.9.2->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.9/site-packages (from librosa==0.9.2->-r requirements.txt (line 4)) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from librosa==0.9.2->-r requirements.txt (line 4)) (23.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/site-packages (from numba==0.56.4->-r requirements.txt (line 5)) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from numba==0.56.4->-r requirements.txt (line 5)) (68.2.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (23.2.1)
# Requirement already satisfied: aiohttp~=3.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (3.10.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (5.3.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (0.112.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (0.4.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (0.24.5)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: markdown-it-py>=2.0.0 in /usr/local/lib/python3.9/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.38.0->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (3.9.0)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (0.3.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (3.10.6)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (10.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (0.0.9)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (0.30.5)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.9/site-packages (from gradio==3.38.0->-r requirements.txt (line 7)) (11.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/site-packages (from gradio_client==0.8.1->-r requirements.txt (line 8)) (2024.5.0)
# Requirement already satisfied: jamo in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: kaldiio>=2.17.0 in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (2.18.0)
# Requirement already satisfied: torch-complex in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (0.4.4)
# Requirement already satisfied: pytorch-wpe in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (0.0.1)
# Requirement already satisfied: editdistance>=0.5.2 in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (0.8.1)
# Requirement already satisfied: oss2 in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (2.18.6)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (0.5.6)
# Requirement already satisfied: jaconv in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (0.4.0)
# Requirement already satisfied: hydra-core>=1.3.2 in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (1.3.2)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (2.6.2.2)
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.9/site-packages (from funasr==1.0.27->-r requirements.txt (line 13)) (20230306)
# Requirement already satisfied: addict in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (24.1.0)
# Requirement already satisfied: datasets>=2.14.5 in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (2.20.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (0.8.0)
# Requirement already satisfied: filelock>=3.3.0 in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (3.15.4)
# Requirement already satisfied: gast>=0.2.2 in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (0.6.0)
# Requirement already satisfied: pyarrow!=9.0.0,>=6.0.0 in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (17.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (2.9.0.post0)
# Requirement already satisfied: simplejson>=3.3.0 in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (3.19.2)
# Requirement already satisfied: sortedcontainers>=1.5.9 in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (2.4.0)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (1.26.18)
# Requirement already satisfied: yapf in /usr/local/lib/python3.9/site-packages (from modelscope==1.10.0->-r requirements.txt (line 19)) (0.40.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 3)) (1.65.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 3)) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 3)) (4.25.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/site-packages (from tensorboard->-r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.9/site-packages (from pytorch-lightning->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.9/site-packages (from pytorch-lightning->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.9/site-packages (from pytorch-lightning->-r requirements.txt (line 6)) (0.11.6)
# Requirement already satisfied: future in /usr/local/lib/python3.9/site-packages (from ffmpeg-python->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.9/site-packages (from onnxruntime-gpu->-r requirements.txt (line 11)) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.9/site-packages (from onnxruntime-gpu->-r requirements.txt (line 11)) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/site-packages (from onnxruntime-gpu->-r requirements.txt (line 11)) (1.13.1)
# Requirement already satisfied: proces>=0.1.3 in /usr/local/lib/python3.9/site-packages (from cn2an->-r requirements.txt (line 14)) (0.1.7)
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.9/site-packages (from g2p_en->-r requirements.txt (line 17)) (3.8.1)
# Requirement already satisfied: inflect>=0.3.1 in /usr/local/lib/python3.9/site-packages (from g2p_en->-r requirements.txt (line 17)) (7.3.1)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.9/site-packages (from g2p_en->-r requirements.txt (line 17)) (0.1.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.9/site-packages (from torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->pytorch-lightning->-r requirements.txt (line 6)) (12.6.20)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 21)) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 21)) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 21)) (0.19.1)
# Requirement already satisfied: py3langid>=0.2.2 in /usr/local/lib/python3.9/site-packages (from LangSegment>=0.2.0->-r requirements.txt (line 27)) (0.2.2)
# Requirement already satisfied: av<13,>=11.0 in /usr/local/lib/python3.9/site-packages (from Faster_Whisper->-r requirements.txt (line 28)) (12.3.0)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /usr/local/lib/python3.9/site-packages (from Faster_Whisper->-r requirements.txt (line 28)) (4.3.1)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.9/site-packages (from Faster_Whisper->-r requirements.txt (line 28)) (1.18.1)
# Requirement already satisfied: python-mecab-ko-dic in /usr/local/lib/python3.9/site-packages (from python_mecab_ko->-r requirements.txt (line 37)) (2.1.1.post2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.9/site-packages (from aiohttp~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/site-packages (from aiohttp~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/site-packages (from aiohttp~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/site-packages (from aiohttp~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/site-packages (from aiohttp~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.9/site-packages (from aiohttp~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (4.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio==3.38.0->-r requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio==3.38.0->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.9/site-packages (from datasets>=2.14.5->modelscope==1.10.0->-r requirements.txt (line 19)) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.9/site-packages (from datasets>=2.14.5->modelscope==1.10.0->-r requirements.txt (line 19)) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/site-packages (from datasets>=2.14.5->modelscope==1.10.0->-r requirements.txt (line 19)) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/site-packages (from datasets>=2.14.5->modelscope==1.10.0->-r requirements.txt (line 19)) (0.70.16)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.9/site-packages (from hydra-core>=1.3.2->funasr==1.0.27->-r requirements.txt (line 13)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.9/site-packages (from hydra-core>=1.3.2->funasr==1.0.27->-r requirements.txt (line 13)) (4.9.3)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.9/site-packages (from inflect>=0.3.1->g2p_en->-r requirements.txt (line 17)) (10.3.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.9/site-packages (from inflect>=0.3.1->g2p_en->-r requirements.txt (line 17)) (4.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard->-r requirements.txt (line 3)) (8.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/site-packages (from markdown-it-py>=2.0.0->markdown-it-py[linkify]>=2.0.0->gradio==3.38.0->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.9/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.38.0->-r requirements.txt (line 7)) (2.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib~=3.0->gradio==3.38.0->-r requirements.txt (line 7)) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/site-packages (from nltk>=3.2.4->g2p_en->-r requirements.txt (line 17)) (8.1.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio==3.38.0->-r requirements.txt (line 7)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio==3.38.0->-r requirements.txt (line 7)) (2024.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.9/site-packages (from pooch>=1.0->librosa==0.9.2->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.38.0->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.38.0->-r requirements.txt (line 7)) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests~=2.0->gradio==3.38.0->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests~=2.0->gradio==3.38.0->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests~=2.0->gradio==3.38.0->-r requirements.txt (line 7)) (2024.7.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa==0.9.2->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa==0.9.2->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.9/site-packages (from uvicorn>=0.14.0->gradio==3.38.0->-r requirements.txt (line 7)) (0.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.9/site-packages (from coloredlogs->onnxruntime-gpu->-r requirements.txt (line 11)) (10.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.9/site-packages (from fastapi->gradio==3.38.0->-r requirements.txt (line 7)) (0.37.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.9/site-packages (from httpx->gradio==3.38.0->-r requirements.txt (line 7)) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.9/site-packages (from httpx->gradio==3.38.0->-r requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/site-packages (from httpx->gradio==3.38.0->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: crcmod>=1.7 in /usr/local/lib/python3.9/site-packages (from oss2->funasr==1.0.27->-r requirements.txt (line 13)) (1.7)
# Requirement already satisfied: pycryptodome>=3.4.7 in /usr/local/lib/python3.9/site-packages (from oss2->funasr==1.0.27->-r requirements.txt (line 13)) (3.20.0)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /usr/local/lib/python3.9/site-packages (from oss2->funasr==1.0.27->-r requirements.txt (line 13)) (2.16.3)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /usr/local/lib/python3.9/site-packages (from oss2->funasr==1.0.27->-r requirements.txt (line 13)) (2.15.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.9/site-packages (from sympy->onnxruntime-gpu->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.9/site-packages (from umap-learn->funasr==1.0.27->-r requirements.txt (line 13)) (0.5.13)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.9/site-packages (from yapf->modelscope==1.10.0->-r requirements.txt (line 19)) (2.0.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /usr/local/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2->funasr==1.0.27->-r requirements.txt (line 13)) (0.10.0)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/local/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2->funasr==1.0.27->-r requirements.txt (line 13)) (41.0.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.2->-r requirements.txt (line 4)) (2.21)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r requirements.txt (line 3)) (3.19.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.38.0->-r requirements.txt (line 7)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.38.0->-r requirements.txt (line 7)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.38.0->-r requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.9/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.38.0->-r requirements.txt (line 7)) (1.0.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.9/site-packages (from anyio->httpx->gradio==3.38.0->-r requirements.txt (line 7)) (1.2.2)

# %%
# @title Download pretrained models 下载预训练模型
# !mkdir -p /content/GPT-SoVITS/GPT_SoVITS/pretrained_models
# !mkdir -p /content/GPT-SoVITS/tools/damo_asr/models
# !mkdir -p /content/GPT-SoVITS/tools/uvr5
# %cd /content/GPT-SoVITS/GPT_SoVITS/pretrained_models
# !git clone https://huggingface.co/lj1995/GPT-SoVITS
# %cd /content/GPT-SoVITS/tools/damo_asr/models
# !git clone https://www.modelscope.cn/damo/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch.git
# !git clone https://www.modelscope.cn/damo/speech_fsmn_vad_zh-cn-16k-common-pytorch.git
# !git clone https://www.modelscope.cn/damo/punc_ct-transformer_zh-cn-common-vocab272727-pytorch.git
# @title UVR5 pretrains 安装uvr5模型
# %cd /content/GPT-SoVITS/tools/uvr5
# %rm -r uvr5_weights
# !git clone https://huggingface.co/Delik/uvr5_weights
# !git config core.sparseCheckout true
# !mv /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/GPT-SoVITS/* /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/
# Out:
# /content/GPT-SoVITS/GPT_SoVITS/pretrained_models
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 23 (delta 2), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (23/23), 103.39 KiB | 3.13 MiB/s, done.
# Filtering content: 100% (5/5), 1.11 GiB | 63.94 MiB/s, done.
# /content/GPT-SoVITS/tools/damo_asr/models
# Cloning into 'speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch'...
# remote: Enumerating objects: 465, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 465 (delta 32), reused 47 (delta 24), pack-reused 408
# Receiving objects: 100% (465/465), 1.12 GiB | 13.02 MiB/s, done.
# Resolving deltas: 100% (267/267), done.
# Cloning into 'speech_fsmn_vad_zh-cn-16k-common-pytorch'...
# remote: Enumerating objects: 184, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 184 (delta 18), reused 23 (delta 10), pack-reused 145
# Receiving objects: 100% (184/184), 4.66 MiB | 4.26 MiB/s, done.
# Resolving deltas: 100% (91/91), done.
# Cloning into 'punc_ct-transformer_zh-cn-common-vocab272727-pytorch'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 170 (delta 25), reused 30 (delta 14), pack-reused 120
# Receiving objects: 100% (170/170), 257.56 MiB | 12.86 MiB/s, done.
# Resolving deltas: 100% (86/86), done.
# /content/GPT-SoVITS/tools/uvr5
# Cloning into 'uvr5_weights'...
# remote: Enumerating objects: 15, done.
# remote: Total 15 (delta 0), reused 0 (delta 0), pack-reused 15 (from 1)
# Unpacking objects: 100% (15/15), 3.25 KiB | 833.00 KiB/s, done.
# Filtering content: 100% (9/9), 594.44 MiB | 61.48 MiB/s, done.

# %%
# @title launch WebUI 启动WebUI
# !/usr/local/bin/pip install ipykernel
# !sed -i '10s/False/True/' /content/GPT-SoVITS/config.py
# %cd /content/GPT-SoVITS/
# !/usr/local/bin/python  webui.py
